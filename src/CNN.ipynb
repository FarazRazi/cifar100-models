# %%
import tensorflow as tf
import keras
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.datasets.cifar10 import load_data

import random
import numpy as np

# %%
def DataLoad(subset=None):
  (x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
  
  if subset is not None:
    train_length = int(len(x_train) * subset)
    x_train = x_train[:train_length]
    y_train = y_train[:train_length]
    
    test_length = int(len(x_test) * subset)
    x_test = x_test[:test_length]
    y_test = y_test[:test_length]
  
  val_split = 0.2
  val_length = int(len(x_train) * val_split)
  x_val = x_train[:val_length]
  y_val = y_train[:val_length]
  
  x_train = x_train[val_length:]
  y_train = y_train[val_length:]
  
  return x_train, y_train, x_val, y_val, x_test, y_test

x_train, y_train, x_val, y_val, x_test, y_test = DataLoad()

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((40000, 32, 32, 3),
#  (40000, 1),
#  (10000, 32, 32, 3),
#  (10000, 1),
#  (10000, 32, 32, 3),
#  (10000, 1))

# %%
# Labels
lables = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
}

# %%
# Plot the 10 images from each label
fig, axes = plt.subplots(10, 11, figsize=(10, 10))

for i in range(10):
    axes[i, 0].text(0, 0.5, lables[i], fontsize=12, ha='center')
    axes[i, 0].axis('off')
    for j in range(1, 11):  
        index = random.choice(np.where(y_train == i)[0])
        axes[i, j].imshow(x_train[index])
        axes[i, j].axis('off')

# %%
# CNN Model
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.name = 'cifar10_cnn'

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001),
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# e:\School_Projects\CIFAR-10 Models\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "cifar10_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_61 (Conv2D)              │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_53 (MaxPooling2D) │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_62 (Conv2D)              │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_54 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_63 (Conv2D)              │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_55 (MaxPooling2D) │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_15 (Flatten)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 167,818 (655.54 KB)
#  Trainable params: 167,818 (655.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - accuracy: 0.2480 - loss: 2.5105 - val_accuracy: 0.4237 - val_loss: 1.6061
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.4503 - loss: 1.5392 - val_accuracy: 0.4992 - val_loss: 1.4013
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - accuracy: 0.5285 - loss: 1.3310 - val_accuracy: 0.5340 - val_loss: 1.3091
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - accuracy: 0.5689 - loss: 1.2180 - val_accuracy: 0.5638 - val_loss: 1.2455
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - accuracy: 0.6229 - loss: 1.0859 - val_accuracy: 0.5834 - val_loss: 1.1857
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - accuracy: 0.6469 - loss: 1.0061 - val_accuracy: 0.6168 - val_loss: 1.1130
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.6732 - loss: 0.9336 - val_accuracy: 0.6160 - val_loss: 1.1231
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - accuracy: 0.7030 - loss: 0.8559 - val_accuracy: 0.6408 - val_loss: 1.0479
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7212 - loss: 0.7963 - val_accuracy: 0.6358 - val_loss: 1.0641
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - accuracy: 0.7386 - loss: 0.7494 - val_accuracy: 0.6436 - val_loss: 1.0609
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.7667 - loss: 0.6821 - val_accuracy: 0.6545 - val_loss: 1.0400
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - accuracy: 0.7828 - loss: 0.6350 - val_accuracy: 0.6334 - val_loss: 1.1312
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.7940 - loss: 0.5945 - val_accuracy: 0.6519 - val_loss: 1.0834
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.8145 - loss: 0.5440 - val_accuracy: 0.6492 - val_loss: 1.1032
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.8240 - loss: 0.5083 - val_accuracy: 0.6598 - val_loss: 1.1062
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.8417 - loss: 0.4638 - val_accuracy: 0.6637 - val_loss: 1.1177
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - accuracy: 0.8553 - loss: 0.4241 - val_accuracy: 0.6554 - val_loss: 1.1668
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.8710 - loss: 0.3886 - val_accuracy: 0.6600 - val_loss: 1.1896
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.8814 - loss: 0.3501 - val_accuracy: 0.6457 - val_loss: 1.2633
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.8959 - loss: 0.3175 - val_accuracy: 0.6549 - val_loss: 1.2801
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - accuracy: 0.8996 - loss: 0.2940 - val_accuracy: 0.6528 - val_loss: 1.3310
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - accuracy: 0.9130 - loss: 0.2622 - val_accuracy: 0.6465 - val_loss: 1.4072
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9229 - loss: 0.2455 - val_accuracy: 0.6551 - val_loss: 1.4034
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.9335 - loss: 0.2097 - val_accuracy: 0.6468 - val_loss: 1.4857
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.9370 - loss: 0.1964 - val_accuracy: 0.6553 - val_loss: 1.5132
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 30s 24ms/step - accuracy: 0.9461 - loss: 0.1713 - val_accuracy: 0.6543 - val_loss: 1.5921
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.9534 - loss: 0.1517 - val_accuracy: 0.6541 - val_loss: 1.6509
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - accuracy: 0.9578 - loss: 0.1341 - val_accuracy: 0.6459 - val_loss: 1.7236
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 29s 23ms/step - accuracy: 0.9626 - loss: 0.1259 - val_accuracy: 0.6548 - val_loss: 1.7553
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 29s 23ms/step - accuracy: 0.9649 - loss: 0.1139 - val_accuracy: 0.6574 - val_loss: 1.8070
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 31s 25ms/step - accuracy: 0.9728 - loss: 0.0967 - val_accuracy: 0.6515 - val_loss: 1.9184
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 29s 23ms/step - accuracy: 0.9724 - loss: 0.0924 - val_accuracy: 0.6517 - val_loss: 1.9131
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 30s 24ms/step - accuracy: 0.9765 - loss: 0.0809 - val_accuracy: 0.6501 - val_loss: 2.0156
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - accuracy: 0.9768 - loss: 0.0781 - val_accuracy: 0.6542 - val_loss: 2.0156
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - accuracy: 0.9843 - loss: 0.0583 - val_accuracy: 0.6553 - val_loss: 2.1333
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 35s 28ms/step - accuracy: 0.9769 - loss: 0.0743 - val_accuracy: 0.6526 - val_loss: 2.1953
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 32s 26ms/step - accuracy: 0.9861 - loss: 0.0526 - val_accuracy: 0.6533 - val_loss: 2.1773
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 30s 24ms/step - accuracy: 0.9842 - loss: 0.0538 - val_accuracy: 0.6456 - val_loss: 2.3398
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - accuracy: 0.9867 - loss: 0.0468 - val_accuracy: 0.6527 - val_loss: 2.2832
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 34s 27ms/step - accuracy: 0.9822 - loss: 0.0596 - val_accuracy: 0.6474 - val_loss: 2.3370
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 35s 28ms/step - accuracy: 0.9853 - loss: 0.0507 - val_accuracy: 0.6507 - val_loss: 2.4420
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 31ms/step - accuracy: 0.9839 - loss: 0.0532 - val_accuracy: 0.6484 - val_loss: 2.4243
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - accuracy: 0.9843 - loss: 0.0503 - val_accuracy: 0.6542 - val_loss: 2.4325
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 37s 29ms/step - accuracy: 0.9845 - loss: 0.0482 - val_accuracy: 0.6412 - val_loss: 2.5582
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 34s 27ms/step - accuracy: 0.9874 - loss: 0.0422 - val_accuracy: 0.6499 - val_loss: 2.6060
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 34s 27ms/step - accuracy: 0.9873 - loss: 0.0427 - val_accuracy: 0.6504 - val_loss: 2.4755
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 30s 24ms/step - accuracy: 0.9903 - loss: 0.0343 - val_accuracy: 0.6490 - val_loss: 2.5839
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 32s 25ms/step - accuracy: 0.9877 - loss: 0.0418 - val_accuracy: 0.6442 - val_loss: 2.7501
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 30s 24ms/step - accuracy: 0.9792 - loss: 0.0609 - val_accuracy: 0.6492 - val_loss: 2.6596
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 31s 25ms/step - accuracy: 0.9898 - loss: 0.0336 - val_accuracy: 0.6503 - val_loss: 2.7125

# %%
# Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
# test model

test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)

print(test_acc)

# Save the model with accuracy
path = '../models/'

model_name = 'cnn'

keras.saving.save_model(model, path + model_name + '_' + str(int(test_acc*100)) + '.keras')
# Out:
# 313/313 - 3s - 11ms/step - accuracy: 0.6532 - loss: 2.7728
# 0.6531999707221985

# %%
# Show the results in tabular form with the following evaluation metrics:
# Accuracy, precision, recall, f1-score, Top-5 Accuracy

from sklearn.metrics import classification_report

y_pred = model.predict(x_test)

y_pred = np.argmax(y_pred, axis=1)

print(classification_report(y_test, y_pred, target_names=lables.values()))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
#               precision    recall  f1-score   support
#
#     airplane       0.63      0.76      0.69      1000
#   automobile       0.79      0.75      0.77      1000
#         bird       0.60      0.49      0.54      1000
#          cat       0.46      0.47      0.47      1000
#         deer       0.61      0.57      0.59      1000
#          dog       0.52      0.58      0.55      1000
#         frog       0.74      0.75      0.74      1000
#        horse       0.72      0.67      0.69      1000
#         ship       0.75      0.77      0.76      1000
#        truck       0.74      0.72      0.73      1000
#
#     accuracy                           0.65     10000
#    macro avg       0.66      0.65      0.65     10000
# weighted avg       0.66      0.65      0.65     10000

# %%
# Display confusion matrix, Receiver Operating Characteristic (ROC) Curve and Area Under the Curve (AUC)

from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=lables.values(), yticklabels=lables.values())

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(10):
    fpr[i], tpr[i], _ = roc_curve(y_test, y_pred, pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])
    
plt.figure(figsize=(10, 10))

for i in range(10):
    plt.plot(fpr[i], tpr[i], label=lables[i] + ' (AUC = %0.2f)' % roc_auc[i])
    
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
